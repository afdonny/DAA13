# %%
def bfs (graph, start):
    visited = [] 
    queue = [start]

    while queue:
        node = queue.pop(0)
        if node not in visited:
            visited.append (node)
            neighbours = graph [node]
            for neighbour in neighbours:
                queue.append(neighbour)
    return visited

# %%
graph={'Amin': {'Wasim', 'Nick', 'Mike'},
        'Wasim' : {'Imran', 'Amin'},
        'Imran' : {'Wasim', 'Faras'},
        'Faras' : {'Imran'},
        'Mike': {'Amin'},
        'Nick': {'Amin'}}

# %%
bfs(graph,'Amin')
# Out:
# ['Amin', 'Mike', 'Nick', 'Wasim', 'Imran', 'Faras']

# %%
bfs(graph,'Wasim')
# Out:
# ['Wasim', 'Amin', 'Imran', 'Mike', 'Nick', 'Faras']

# %%
bfs(graph,'Faras')
# Out:
# ['Faras', 'Imran', 'Wasim', 'Amin', 'Mike', 'Nick']

# %%
#Latihan 1
graph={'Rektor': {'Warek 1', 'Warek 2'},
       'Warek 1' : {'Rektor'},
       'Warek 2' : {'Kaprodi 3', 'Kaprodi 1', 'Kaprodi 2', 'Rektor'},
       'Kaprodi 1' : {'Dosen A', 'Dosen B', 'Dosen C', 'Warek 2'},
       'Kaprodi 2' : {'Dosen D', 'Dosen E', 'Warek 2'},
       'Kaprodi 3' : {'Dosen F', 'Dosen G', 'Warek 2'},
       'Dosen A' : {'Kaprodi 1'},
       'Dosen B' : {'Kaprodi 1'},
       'Dosen C' : {'Kaprodi 1'},
       'Dosen D' : {'Kaprodi 2'},
       'Dosen E' : {'Kaprodi 2'},
       'Dosen F' : {'Kaprodi 3'},
       'Dosen G' : {'Kaprodi 3'}}

# %%
bfs(graph,'Rektor')
# Out:
# ['Rektor',
#  'Warek 2',
#  'Warek 1',
#  'Kaprodi 3',
#  'Kaprodi 2',
#  'Kaprodi 1',
#  'Dosen F',
#  'Dosen G',
#  'Dosen E',
#  'Dosen D',
#  'Dosen A',
#  'Dosen B',
#  'Dosen C']

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()
    visited.add(start)
    print(start)
    for next in graph[start] - visited:
          dfs (graph, next, visited)
    return visited

# %%
graph={'Amin': {'Wasim', 'Nick', 'Mike'},
        'Wasim' : {'Imran', 'Amin'},
        'Imran' : {'Wasim', 'Faras'},
        'Faras' : {'Imran'},
        'Mike': {'Amin'},
        'Nick': {'Amin'}}

# %%
dfs(graph, 'Amin')
# Out:
# Amin
# Mike
# Nick
# Wasim
# Imran
# Faras
# {'Amin', 'Faras', 'Imran', 'Mike', 'Nick', 'Wasim'}

# %%
dfs(graph, 'Wasim')
# Out:
# Wasim
# Amin
# Mike
# Nick
# Imran
# Faras
# {'Amin', 'Faras', 'Imran', 'Mike', 'Nick', 'Wasim'}

# %%
dfs(graph, 'Faras')
# Out:
# Faras
# Imran
# Wasim
# Amin
# Mike
# Nick
# {'Amin', 'Faras', 'Imran', 'Mike', 'Nick', 'Wasim'}

# %%
# o Amin -------------------
# |             |          |
# o Wasim       o Nick     o Mike
# |
# o Imran
# |
# o Faras
#
# turun dari amnin ke Faras, geser ke nick & mike
dfs(graph, 'Nick')
# Out:
# Nick
# Amin
# Mike
# Wasim
# Imran
# Faras
# {'Amin', 'Faras', 'Imran', 'Mike', 'Nick', 'Wasim'}

# %%
#Latihan 2
graph={'Rektor': {'Warek 1', 'Warek 2'},
       'Warek 1' : {'Rektor'},
       'Warek 2' : {'Kaprodi 3', 'Kaprodi 1', 'Kaprodi 2', 'Rektor'},
       'Kaprodi 1' : {'Dosen A', 'Dosen B', 'Dosen C', 'Warek 2'},
       'Dosen A' : {'Kaprodi 1'},
       'Dosen B' : {'Kaprodi 1'},
       'Dosen C' : {'Kaprodi 1'},
       'Kaprodi 2' : {'Dosen D', 'Dosen E', 'Warek 2'},
       'Dosen D' : {'Kaprodi 2'},
       'Dosen E' : {'Kaprodi 2'},
       'Kaprodi 3' : {'Warek 2', 'Dosen F', 'Dosen G'},
       'Dosen F' : {'Kaprodi 3'},
       'Dosen G' : {'Kaprodi 3'}}

# %%
dfs(graph, 'Rektor')
# Out:
# Rektor
# Warek 2
# Kaprodi 3
# Dosen F
# Dosen G
# Kaprodi 1
# Dosen A
# Dosen B
# Dosen C
# Kaprodi 2
# Dosen E
# Dosen D
# Warek 1
# {'Dosen A',
#  'Dosen B',
#  'Dosen C',
#  'Dosen D',
#  'Dosen E',
#  'Dosen F',
#  'Dosen G',
#  'Kaprodi 1',
#  'Kaprodi 2',
#  'Kaprodi 3',
#  'Rektor',
#  'Warek 1',
#  'Warek 2'}
